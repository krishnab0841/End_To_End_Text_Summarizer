# %%
import os

# %%
# %pwd
# Out:
# 'd:\\End_To_End_Text_Summarizer\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\End_To_End_Text_Summarizer'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataValidationConfig:
    root_dir: Path
    STATUS_FILE: str
    ALL_REQUIRED_FILES: list

# %%
from TextSummarizer.constants import *
from TextSummarizer.utils.common import read_yaml, create_directories
# Out:
# [2025-11-17 13:37:20,396: INFO: __init__: >>>>>> stage Data Ingestion stage started <<<<<<]
# [2025-11-17 13:37:20,417: INFO: common: yaml file: D:\End_To_End_Text_Summarizer\config\config.yaml loaded successfully]
# [2025-11-17 13:37:20,421: INFO: common: yaml file: D:\End_To_End_Text_Summarizer\params.yaml loaded successfully]
# [2025-11-17 13:37:20,424: INFO: common: Created directory at: artifacts_root]
# [2025-11-17 13:37:20,427: INFO: common: Created directory at: artifacts/data_ingestion]
# [2025-11-17 13:37:20,433: INFO: data_ingestion: File already exists of size: 7718 KB]
# [2025-11-17 13:37:21,092: INFO: __init__: >>>>>> stage Data Ingestion stage completed <<<<<<
#
# x==========x]

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_validation_config(self) -> DataValidationConfig:
        config = self.config.data_validation

        create_directories([config.root_dir])

        data_validation_config = DataValidationConfig(
            root_dir=config.root_dir,
            STATUS_FILE=config.STATUS_FILE,
            ALL_REQUIRED_FILES=config.ALL_REQUIRED_FILES,
        )

        return data_validation_config

# %%
import os
from TextSummarizer.logging import logger

# %%
class DataValiadtion:
    def __init__(self, config: DataValidationConfig):
        self.config = config


    
    def validate_all_files_exist(self)-> bool:
        try:
            validation_status = None

            all_files = os.listdir(os.path.join("artifacts","data_ingestion","samsum_dataset"))

            for file in all_files:
                if file not in self.config.ALL_REQUIRED_FILES:
                    validation_status = False
                    with open(self.config.STATUS_FILE, 'w') as f:
                        f.write(f"Validation status: {validation_status}")
                else:
                    validation_status = True
                    with open(self.config.STATUS_FILE, 'w') as f:
                        f.write(f"Validation status: {validation_status}")

            return validation_status
        
        except Exception as e:
            raise e

# %%
try:
    config = ConfigurationManager()
    data_validation_config = config.get_data_validation_config()
    data_validation = DataValiadtion(config=data_validation_config)
    data_validation.validate_all_files_exist()
except Exception as e:
    raise e
# Out:
# [2025-11-17 13:43:20,376: INFO: common: yaml file: D:\End_To_End_Text_Summarizer\config\config.yaml loaded successfully]
# [2025-11-17 13:43:20,380: INFO: common: yaml file: D:\End_To_End_Text_Summarizer\params.yaml loaded successfully]
# [2025-11-17 13:43:20,385: INFO: common: Created directory at: artifacts_root]
# [2025-11-17 13:43:20,388: INFO: common: Created directory at: artifacts/data_validation]
